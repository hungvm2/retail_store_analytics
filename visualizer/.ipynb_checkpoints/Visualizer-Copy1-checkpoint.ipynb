# %%
from visualize import Visualizer

# %%
visualizer = Visualizer()

# %%
visualizer.show_heatmap1(start_time="2022-03-22", end_time="2022-03-26")

# %%
visualizer.show_heatmap2(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 visualizer.show_heatmap2(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59")
#
# File /mnt/Data/MasterofDataScience/Phat trien phan mem nang cao cho tinh toan khoa hoc/retail_store_analytics/visualizer/visualize.py:114, in Visualizer.show_heatmap2(self, start_time, end_time)
#     112 ax.imshow(im, extent=[x.min(), x.max(), y.min(), y.max()], aspect="auto")
#     113 # Create colorbar
# --> 114 cbar = ax.figure.colorbar(im, ax=ax)
#     115 cbar.ax.set_ylabel("customer density", rotation=-90, va="bottom")
#
# File ~/anaconda3/envs/retail_store/lib/python3.9/site-packages/matplotlib/figure.py:1210, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    1206 NON_COLORBAR_KEYS = ['fraction', 'pad', 'shrink', 'aspect', 'anchor',
# ...

# %%
visualizer.show_barchart(start_time="2022-03-22", end_time="2022-03-26")
