# %%
from visualize import Visualizer

# %%
visualizer = Visualizer()

# %%
visualizer.show_heatmap1(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59")

# %%
visualizer.show_barchart(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59")
# Out:
# /mnt/Data/MasterofDataScience/Phat trien phan mem nang cao cho tinh toan khoa hoc/retail_store_analytics/visualizer/visualize.py:69: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(x, rotation='vertical')
