# %%
from visualize import Visualizer
import warnings
warnings.filterwarnings("ignore")

# %%
visualizer = Visualizer()

# %%
visualizer.show_heatmap(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59", cam_id=1)

# %%
visualizer.show_barchart(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59", cam_id=3)
