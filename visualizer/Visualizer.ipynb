# %%
from visualize import Visualizer

# %%
visualizer = Visualizer()

# %%
visualizer.show_heatmap1(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59")

# %%
visualizer.show_heatmap2(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 visualizer.show_heatmap2(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59")
#
# File /mnt/Data/MasterofDataScience/Phat trien phan mem nang cao cho tinh toan khoa hoc/retail_store_analytics/visualizer/visualize.py:116, in Visualizer.show_heatmap2(self, start_time, end_time)
#     114 im = ax.imshow(img, extent=[x.min(), x.max(), y.min(), y.max()], aspect="auto")
#     115 # Create colorbar
# --> 116 ax.figure.clim(0, max_count)
#     117 cbar = ax.figure.colorbar(im, ax=ax)
#     118 cbar.ax.set_ylabel("customer density", rotation=-90, va="bottom")
#
# AttributeError: 'Figure' object has no attribute 'clim'

# %%
visualizer.show_barchart(start_time="2022-03-26 0:00:00", end_time="2022-03-26 23:59:59")
